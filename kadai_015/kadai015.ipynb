# %%
class Human:
  def __init__(self, name, age):
     self.name = name
     self.age = age

  def printinfo(self):
    print("名前:", self.name)
    print("年齢:", self.age)

tani = Human("yuki", 28)

tani.printinfo()
# Out:
# 名前: yuki
# 年齢: 28
